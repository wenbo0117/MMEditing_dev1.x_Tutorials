# %% [markdown]
# ## 安装配置 MMEditing 环境
#
# MMEditing 是一个处理、编辑和合成图像与视频的开源工具箱。
#
# MMEditing 允许研究人员和工程师使用最先进的预训练模型，并且可以轻松训练和开发新的定制模型。
#
# MMEditing 支持各种基础生成模型，包括：无条件生成对抗网络、条件生成对抗网络、内部学习
#
# MMEditing主页：https://github.com/open-mmlab/mmediting
#
# OpenMMLab主页：https://openmmlab.com/
#
# 直接按顺序逐行运行本 notebook 的所有代码块，即可安装 MMCV 和 MMEditing 环境。
#
# 云GPU环境参数：GPU RTX 3060、CUDA v11.2
#
# 代码在以下环境测试：https://featurize.cn?s=2d02acf34e5e47368c46f6bc33a81ef6

# %% [markdown]
# ## 下载安装Pytorch、mmcv -full（大约需要两分钟）

# %% [markdown]
# > 提示：以下代码运行时，若长时间运行卡着不动，可重启 kernel 后重新运行一遍

# %%
# 安装 Pytorch
# !pip3 install install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# 安装 openmim
# !pip install -U openmim
# 安装mmcv
# !mim install 'mmcv>=2.0.0rc1'
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Collecting install
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4d/c8/8cbca135f9e167810756ea2bc34b028501936675fcbd7dadccf752fa4622/install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting torch==1.10.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.1%2Bcu113-cp37-cp37m-linux_x86_64.whl (1821.5 MB)
#      |████████████▊                   | 722.7 MB 105.4 MB/s eta 0:00:11
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |██████████████████▌             | 1054.7 MB 101.3 MB/s eta 0:00:08
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████▎       | 1383.6 MB 89.8 MB/s eta 0:00:056
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |██████████████████████████████  | 1705.7 MB 92.2 MB/s eta 0:00:022
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 1821.5 MB 95.5 MB/s eta 0:00:01
# Collecting torchvision==0.11.2+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.2%2Bcu113-cp37-cp37m-linux_x86_64.whl (24.6 MB)
#      |████████████████████████████████| 24.6 MB 65.2 MB/s eta 0:00:01
# Collecting torchaudio==0.10.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.10.1%2Bcu113-cp37-cp37m-linux_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 61.9 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /environment/miniconda3/lib/python3.7/site-packages (from torch==1.10.1+cu113) (4.0.1)
# Requirement already satisfied: numpy in /environment/miniconda3/lib/python3.7/site-packages (from torchvision==0.11.2+cu113) (1.21.4)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /environment/miniconda3/lib/python3.7/site-packages (from torchvision==0.11.2+cu113) (8.4.0)
# Installing collected packages: torch, torchvision, torchaudio, install
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu113
#     Uninstalling torch-1.10.0+cu113:
#       Successfully uninstalled torch-1.10.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu113
#     Uninstalling torchvision-0.11.1+cu113:
#       Successfully uninstalled torchvision-0.11.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.10.0+cu113
#     Uninstalling torchaudio-0.10.0+cu113:
#       Successfully uninstalled torchaudio-0.10.0+cu113
# Successfully installed install-1.3.5 torch-1.10.1+cu113 torchaudio-0.10.1+cu113 torchvision-0.11.2+cu113
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting openmim
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ef/2f/dc7ce077629d1234f9cf7f17896cdcd49be0791da99aea673cced49b9700/openmim-0.3.6-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 2.9 MB/s  eta 0:00:01
# Requirement already satisfied: colorama in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (0.4.4)
# Requirement already satisfied: pandas in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (1.3.4)
# Requirement already satisfied: pip>=19.3 in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (21.1.3)
# Requirement already satisfied: Click in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (7.1.2)
# Requirement already satisfied: requests in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (2.24.0)
# Collecting model-index
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0f/a6/4d4cbbef704f186d143e2859296a610a355992e4eae71582bd598093b36a/model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: rich in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (13.3.1)
# Requirement already satisfied: tabulate in /environment/miniconda3/lib/python3.7/site-packages (from openmim) (0.8.7)
# Collecting ordered-set
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/33/55/af02708f230eb77084a299d7b08175cff006dea4f2721074b92cdb0296c0/ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: markdown in /environment/miniconda3/lib/python3.7/site-packages (from model-index->openmim) (3.3.6)
# Requirement already satisfied: pyyaml in /environment/miniconda3/lib/python3.7/site-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /environment/miniconda3/lib/python3.7/site-packages (from markdown->model-index->openmim) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /environment/miniconda3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /environment/miniconda3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /environment/miniconda3/lib/python3.7/site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /environment/miniconda3/lib/python3.7/site-packages (from pandas->openmim) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /environment/miniconda3/lib/python3.7/site-packages (from pandas->openmim) (1.21.4)
# Requirement already satisfied: six>=1.5 in /environment/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->openmim) (1.16.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /environment/miniconda3/lib/python3.7/site-packages (from requests->openmim) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /environment/miniconda3/lib/python3.7/site-packages (from requests->openmim) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /environment/miniconda3/lib/python3.7/site-packages (from requests->openmim) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /environment/miniconda3/lib/python3.7/site-packages (from requests->openmim) (3.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in /environment/miniconda3/lib/python3.7/site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->openmim) (0.1.2)
# Installing collected packages: ordered-set, model-index, openmim
# Successfully installed model-index-0.1.11 openmim-0.3.6 ordered-set-4.1.0
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.10.0/index.html
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu113/torch1.10.0/mmcv-2.0.0rc4-cp37-cp37m-manylinux1_x86_64.whl (59.4 MB)
#      |████████████████████████████████| 59.4 MB 12.8 MB/s eta 0:00:01
# Requirement already satisfied: opencv-python>=3 in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (4.5.4.60)
# Requirement already satisfied: mmengine>=0.2.0 in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (0.6.0)
# Requirement already satisfied: packaging in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (21.3)
# Requirement already satisfied: pyyaml in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (6.0)
# Requirement already satisfied: addict in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: Pillow in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (8.4.0)
# Requirement already satisfied: numpy in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (1.21.4)
# Requirement already satisfied: yapf in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1) (0.31.0)
# Requirement already satisfied: termcolor in /environment/miniconda3/lib/python3.7/site-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.1.0)
# Requirement already satisfied: rich in /environment/miniconda3/lib/python3.7/site-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (13.3.1)
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.7/site-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.0.6)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (0.11.0)
# Requirement already satisfied: setuptools-scm>=4 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (6.3.2)
# Requirement already satisfied: six>=1.5 in /environment/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.2.2)
# Requirement already satisfied: setuptools in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (52.0.0.post20210125)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.14.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (4.0.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in /environment/miniconda3/lib/python3.7/site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (0.1.2)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0rc4

# %% [markdown]
# ## 安装其它工具包(大约需要一分钟)

# %%
# 安装其它工具包
# !pip install ipywidgets tqdm imageio-ffmpeg ninja matplotlib numpy opencv-python prettytable -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: ipywidgets in /environment/miniconda3/lib/python3.7/site-packages (7.6.5)
# Requirement already satisfied: tqdm in /environment/miniconda3/lib/python3.7/site-packages (4.61.2)
# Collecting imageio-ffmpeg
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/dc/3f/fc9a0345a0ef2d9596c3d3d9549ac72377ea97c289abcf3c96f0821c3072/imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      |████████████████████████████████| 26.9 MB 66.5 MB/s eta 0:00:01
# Collecting ninja
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0f/58/854ce5aab0ff5c33d66e1341b0be42f0330797335011880f7fbd88449996/ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      |████████████████████████████████| 145 kB 95.9 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.7/site-packages (3.5.0)
# Requirement already satisfied: numpy in /environment/miniconda3/lib/python3.7/site-packages (1.21.4)
# Requirement already satisfied: opencv-python in /environment/miniconda3/lib/python3.7/site-packages (4.5.4.60)
# Collecting prettytable
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/51/fd/52b6d8a28f8dabf05e5fcbb5ef639d62326a5bccfa93b98fb7e54d414509/prettytable-3.6.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: nbformat>=4.2.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (7.30.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (6.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: importlib-metadata<5 in /environment/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (4.8.2)
# Requirement already satisfied: argcomplete>=1.12.3 in /environment/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.12.3)
# Requirement already satisfied: jupyter-client<8.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in /environment/miniconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: zipp>=0.5 in /environment/miniconda3/lib/python3.7/site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /environment/miniconda3/lib/python3.7/site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets) (4.0.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.23)
# Requirement already satisfied: backcall in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.17.0)
# Requirement already satisfied: pexpect>4.3 in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pickleshare in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (2.14.0)
# Requirement already satisfied: setuptools>=18.5 in /environment/miniconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (52.0.0.post20210125)
# Requirement already satisfied: parso>=0.7.0 in /environment/miniconda3/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /environment/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.4)
# Requirement already satisfied: pyzmq>=13 in /environment/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: entrypoints in /environment/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.1 in /environment/miniconda3/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jsonschema>=2.6 in /environment/miniconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.2.1)
# Requirement already satisfied: fastjsonschema in /environment/miniconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (2.16.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /environment/miniconda3/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /environment/miniconda3/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /environment/miniconda3/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /environment/miniconda3/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /environment/miniconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in /environment/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /environment/miniconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.6)
# Requirement already satisfied: argon2-cffi in /environment/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /environment/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.1)
# Requirement already satisfied: nbconvert in /environment/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (7.0.0)
# Requirement already satisfied: prometheus-client in /environment/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.12.0)
# Requirement already satisfied: jinja2 in /environment/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /environment/miniconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: pillow>=6.2.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (4.28.3)
# Requirement already satisfied: setuptools-scm>=4 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib) (1.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /environment/miniconda3/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.6)
# Requirement already satisfied: pycparser in /environment/miniconda3/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /environment/miniconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: bleach in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.4)
# Requirement already satisfied: defusedxml in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: tinycss2 in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.9)
# Requirement already satisfied: beautifulsoup4 in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.11.1)
# Requirement already satisfied: lxml in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in /environment/miniconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in /environment/miniconda3/lib/python3.7/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: webencodings in /environment/miniconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Installing collected packages: prettytable, ninja, imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.4.8 ninja-1.11.1 prettytable-3.6.0

# %% [markdown]
# ## 下载 MMEditing

# %%
# 删掉原有的mmediting文件夹（如有）
# !rm -rf mmediting

# %%
# 安装MMEngine
# !pip install git+https://github.com/open-mmlab/mmengine.git
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting git+https://github.com/open-mmlab/mmengine.git
#   Cloning https://github.com/open-mmlab/mmengine.git to /tmp/pip-req-build-2byzx8we
#   Running command git clone -q https://github.com/open-mmlab/mmengine.git /tmp/pip-req-build-2byzx8we
# Requirement already satisfied: addict in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (2.4.0)
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (3.5.0)
# Requirement already satisfied: numpy in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (1.21.4)
# Requirement already satisfied: pyyaml in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (6.0)
# Requirement already satisfied: rich in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (13.3.1)
# Requirement already satisfied: termcolor in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (1.1.0)
# Requirement already satisfied: yapf in /environment/miniconda3/lib/python3.7/site-packages (from mmengine==0.6.0) (0.31.0)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (3.0.6)
# Requirement already satisfied: setuptools-scm>=4 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (6.3.2)
# Requirement already satisfied: packaging>=20.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine==0.6.0) (4.28.3)
# Requirement already satisfied: six>=1.5 in /environment/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->mmengine==0.6.0) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->mmengine==0.6.0) (1.2.2)
# Requirement already satisfied: setuptools in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->mmengine==0.6.0) (52.0.0.post20210125)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine==0.6.0) (4.0.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine==0.6.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine==0.6.0) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /environment/miniconda3/lib/python3.7/site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->mmengine==0.6.0) (0.1.2)

# %%
# 从github安装最新版MMEditing
# !git clone -b dev-1.x https://github.com/open-mmlab/mmediting.git
# Out:
# 正克隆到 'mmediting'...
# remote: Enumerating objects: 21652, done.
# remote: Counting objects: 100% (1119/1119), done.
# remote: Compressing objects: 100% (691/691), done.
# remote: Total 21652 (delta 522), reused 868 (delta 419), pack-reused 20533
# 接收对象中: 100% (21652/21652), 16.72 MiB | 17.46 MiB/s, 完成.
# 处理 delta 中: 100% (14561/14561), 完成.
# 正在更新文件: 100% (1464/1464), 完成.

# %% [markdown]
# ## 安装 MMEditing （大约需要2分钟）

# %%
# 进入 mmediting 主目录
import os
os.chdir('mmediting')

# %%
# !pip install -r requirements.txt
# !pip install -v -e .
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Ignoring av: markers 'python_version < "3.7"' don't match your environment
# Collecting clip@ git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1
#   Cloning https://github.com/openai/CLIP.git (to revision d50d76daa670286dd6cacf3bcd80b5e4823fc8e1) to /tmp/pip-install-4yz2koai/clip_e20daa3fedc64afa813c566dbc0827ee
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-install-4yz2koai/clip_e20daa3fedc64afa813c566dbc0827ee
#   Running command git rev-parse -q --verify 'sha^d50d76daa670286dd6cacf3bcd80b5e4823fc8e1'
#   Running command git fetch -q https://github.com/openai/CLIP.git d50d76daa670286dd6cacf3bcd80b5e4823fc8e1
#   Running command git checkout -q d50d76daa670286dd6cacf3bcd80b5e4823fc8e1
# Collecting av
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ac/9b/ace0ec1630646d9698eb4862f6d839558c6073449406e5b02f20bd17f81a/av-10.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.7 MB)
#      |████████████████████████████████| 30.7 MB 66.0 MB/s eta 0:00:01
# Collecting einops
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4b/f7/8557c683501eb14462b60e32d21fc51317ab2ba39688db1b8b7cebe1a274/einops-0.6.0-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 19.1 MB/s eta 0:00:01
# Collecting face-alignment
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/49/9b/bd2e87013d7e3b4a7565a85336298c5089d2800ed696487158c8f9d8c7f0/face_alignment-1.3.5.tar.gz (27 kB)
# Collecting facexlib
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/11/6a/ff94c9e7c9c588bb8429955417960595a1a197488c5b451b84eeac706096/facexlib-0.2.5-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 58.3 MB/s eta 0:00:01
# Collecting lmdb
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/21/e5/7ccaa3d85d733b66128855c293823cb2bebaf4a0c4ca6c5839b15660b3a2/lmdb-1.4.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (299 kB)
#      |████████████████████████████████| 299 kB 82.7 MB/s eta 0:00:01
# Collecting lpips
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9b/13/1df50c7925d9d2746702719f40e864f51ed66f307b20ad32392f1ad2bb87/lpips-0.1.4-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 44.4 MB/s eta 0:00:01
# Requirement already satisfied: mmcv>=2.0.0rc1 in /environment/miniconda3/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 8)) (2.0.0rc4)
# Requirement already satisfied: mmengine in /environment/miniconda3/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 9)) (0.6.0)
# Requirement already satisfied: numpy in /environment/miniconda3/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 10)) (1.21.4)
# Requirement already satisfied: opencv-python!=4.5.5.62,!=4.5.5.64 in /environment/miniconda3/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 11)) (4.5.4.60)
# Requirement already satisfied: Pillow in /environment/miniconda3/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 17)) (8.4.0)
# Collecting resize_right
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1d/08/c5c0640a08d7b373f1175c536462862054ee32145dae457c89916cd568d2/resize_right-0.0.2-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: tensorboard in /environment/miniconda3/lib/python3.7/site-packages (from -r requirements/runtime.txt (line 19)) (2.7.0)
# Collecting coverage<7.0.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0d/ef/8735875a8dc09e1c4e484a5436c8b4148731b70daccc6f203c50b05e7505/coverage-6.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#      |████████████████████████████████| 210 kB 95.4 MB/s eta 0:00:01
# Collecting imageio-ffmpeg==0.4.4
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d0/93/fbdfebeb76d6a44d9224473b6df2575d4443be9b857b88ccf9ef9e251530/imageio_ffmpeg-0.4.4-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      |████████████████████████████████| 26.9 MB 94.0 MB/s eta 0:00:01
# Collecting interrogate
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/85/57/aa8632d8ff7c1b612abf0093b4dce7a1f74de852c548dbd99e1b858cf60f/interrogate-1.5.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 46.5 MB/s eta 0:00:01
# Collecting mmdet>=3.0.0rc2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/80/0d/338e18bb8c3c59857e9b06a7c2af4c6c729c3cddad73706a66a20d4ba0b3/mmdet-3.0.0rc6-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 69.4 MB/s eta 0:00:01
# Collecting pytest
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/cc/02/8f59bf194c9a1ceac6330850715e9ec11e21e2408a30a596c65d54cf4d2a/pytest-7.2.1-py3-none-any.whl (317 kB)
#      |████████████████████████████████| 317 kB 66.2 MB/s eta 0:00:01
# Collecting transformers
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1e/e2/60c3f4691b16d126ee9cfe28f598b13c424b60350ab339aba81aef054b8f/transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 86.9 MB/s eta 0:00:01
# Collecting open_clip_torch
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3d/83/7df144e8ad9627790f9bd21bb82fff3ee926718253476b9bc270a18cf8e1/open_clip_torch-2.15.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 84.8 MB/s eta 0:00:01
# Collecting PyQt5
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/28/99/78db05e606dbb4a9425c159e7f1f64b69683c16ee3dcd0f97ed9ede6b205/PyQt5-5.15.9-cp37-abi3-manylinux_2_17_x86_64.whl (8.4 MB)
#      |████████████████████████████████| 8.4 MB 79.7 MB/s eta 0:00:01
# Collecting ftfy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e1/1e/bf736f9576a8979752b826b75cbd83663ff86634ea3055a766e2d8ad3ee5/ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 35.9 MB/s eta 0:00:01
# Collecting regex
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/42/d8/8a7131e7d0bf237f7bcd3191541a4bf21863c253fe6bee0796900a1a9a29/regex-2022.10.31-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#      |████████████████████████████████| 757 kB 57.1 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /environment/miniconda3/lib/python3.7/site-packages (from clip@ git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1->-r requirements/tests.txt (line 1)) (4.61.2)
# Requirement already satisfied: torch in /environment/miniconda3/lib/python3.7/site-packages (from clip@ git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1->-r requirements/tests.txt (line 1)) (1.10.1+cu113)
# Requirement already satisfied: torchvision in /environment/miniconda3/lib/python3.7/site-packages (from clip@ git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1->-r requirements/tests.txt (line 1)) (0.11.2+cu113)
# Requirement already satisfied: packaging in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->-r requirements/runtime.txt (line 8)) (21.3)
# Requirement already satisfied: addict in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->-r requirements/runtime.txt (line 8)) (2.4.0)
# Requirement already satisfied: pyyaml in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->-r requirements/runtime.txt (line 8)) (6.0)
# Requirement already satisfied: yapf in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->-r requirements/runtime.txt (line 8)) (0.31.0)
# Requirement already satisfied: termcolor in /environment/miniconda3/lib/python3.7/site-packages (from mmengine->-r requirements/runtime.txt (line 9)) (1.1.0)
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.7/site-packages (from mmengine->-r requirements/runtime.txt (line 9)) (3.5.0)
# Requirement already satisfied: rich in /environment/miniconda3/lib/python3.7/site-packages (from mmengine->-r requirements/runtime.txt (line 9)) (13.3.1)
# Collecting terminaltables
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting pycocotools
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ef/c6/90220be3b39fbc4cbd203775ca47dd8dc97fae06fbd2b500637395621b7c/pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scipy in /environment/miniconda3/lib/python3.7/site-packages (from mmdet>=3.0.0rc2->-r requirements/tests.txt (line 12)) (1.7.3)
# Requirement already satisfied: six in /environment/miniconda3/lib/python3.7/site-packages (from mmdet>=3.0.0rc2->-r requirements/tests.txt (line 12)) (1.16.0)
# Requirement already satisfied: scikit-image in /environment/miniconda3/lib/python3.7/site-packages (from face-alignment->-r requirements/runtime.txt (line 4)) (0.19.0)
# Collecting numba
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6b/b5/b0a0af320c43f2925c699e8613382d3669829b585717ef2d795a06187564/numba-0.56.4-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 82.3 MB/s eta 0:00:01
# Collecting filterpy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f6/1d/ac8914360460fafa1990890259b7fa5ef7ba4cd59014e782e4ab3ab144d8/filterpy-1.4.5.zip (177 kB)
#      |████████████████████████████████| 177 kB 72.8 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /environment/miniconda3/lib/python3.7/site-packages (from torch->clip@ git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1->-r requirements/tests.txt (line 1)) (4.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (52.0.0.post20210125)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (2.0.2)
# Requirement already satisfied: wheel>=0.26 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (0.36.2)
# Requirement already satisfied: protobuf>=3.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (3.19.1)
# Requirement already satisfied: grpcio>=1.24.3 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->-r requirements/runtime.txt (line 19)) (1.42.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements/runtime.txt (line 19)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements/runtime.txt (line 19)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements/runtime.txt (line 19)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirements/runtime.txt (line 19)) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /environment/miniconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard->-r requirements/runtime.txt (line 19)) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /environment/miniconda3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements/runtime.txt (line 19)) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /environment/miniconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements/runtime.txt (line 19)) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements/runtime.txt (line 19)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements/runtime.txt (line 19)) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements/runtime.txt (line 19)) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements/runtime.txt (line 19)) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirements/runtime.txt (line 19)) (3.1.1)
# Collecting py
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f6/f0/10642828a8dfb741e5f3fbaac830550a518a775c7fff6f04a007259b0548/py-1.11.0-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 78.0 MB/s eta 0:00:01
# Requirement already satisfied: toml in /environment/miniconda3/lib/python3.7/site-packages (from interrogate->-r requirements/tests.txt (line 11)) (0.10.2)
# Requirement already satisfied: click>=7.1 in /environment/miniconda3/lib/python3.7/site-packages (from interrogate->-r requirements/tests.txt (line 11)) (7.1.2)
# Requirement already satisfied: attrs in /environment/miniconda3/lib/python3.7/site-packages (from interrogate->-r requirements/tests.txt (line 11)) (21.2.0)
# Requirement already satisfied: colorama in /environment/miniconda3/lib/python3.7/site-packages (from interrogate->-r requirements/tests.txt (line 11)) (0.4.4)
# Requirement already satisfied: tabulate in /environment/miniconda3/lib/python3.7/site-packages (from interrogate->-r requirements/tests.txt (line 11)) (0.8.7)
# Collecting iniconfig
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ef/a6/62565a6e1cf69e10f5727360368e451d4b7f58beeac6173dc9db836a5b46/iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /environment/miniconda3/lib/python3.7/site-packages (from pytest->-r requirements/tests.txt (line 13)) (1.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from pytest->-r requirements/tests.txt (line 13)) (1.2.2)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e8/14/9c6a7e5f12294ccd6975a45e02899ed25468cd7c2c86f3d9725f387f9f5f/exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting filelock
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/14/4c/b201d0292ca4e0950f0741212935eac9996f69cd66b92a3587e594999163/filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/82/66/7a476341defe398542f93d4188f85dd71c21933c2806cc669fcbcbe8f429/tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 91.2 MB/s eta 0:00:01
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/57/3f/63dd1710b00aa5e7c186ac761a2078f595abf7bb58ea802138d83cb30cca/huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 98.0 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /environment/miniconda3/lib/python3.7/site-packages (from packaging->mmcv>=2.0.0rc1->-r requirements/runtime.txt (line 8)) (3.0.6)
# Collecting timm
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/89/4e/97622efc48a6e0c11781ed8a3472c679f2c8a5cf6ebd58a57b050e758bfe/timm-0.6.12-py3-none-any.whl (549 kB)
#      |████████████████████████████████| 549 kB 91.1 MB/s eta 0:00:01
# Collecting sentencepiece
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d7/e1/169802f953bd3f5e3dcde6f746d8b833b6c23702f02e5f07908607c9a66e/sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 76.6 MB/s eta 0:00:01
# Collecting open_clip_torch
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/db/9c/7e17b7f4e4767de1f8eb3f96a8a2546aa50b7333d7d691ebc05252cbaeb9/open_clip_torch-2.14.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 68.8 MB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1e/0f/51238c3f45f4cea79cbce92fd9e0ccb72f0b1ed4489e5300b9eb63f3f0a6/open_clip_torch-2.13.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 403 kB/s eta 0:00:01     |███████████████████████████████ | 1.4 MB 403 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0d/36/3174879b693436d10fe8a58d0aad23f4d1ce47c609dd7e2069a4f2e0f969/open_clip_torch-2.12.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 803 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9b/df/037a2070bd9cc11cc4500806239b8503951b3cc413283fcf69d845e29ab1/open_clip_torch-2.11.1-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 578 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e5/e4/867953eb1360141ca355498e06f1fdcaddb886fc47a9b00ac2a9751ffe50/open_clip_torch-2.11.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 1.2 MB/s eta 0:00:01     |█████████████████████████████▉  | 1.4 MB 1.2 MB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b9/98/40e7fa0ce72d833e2a71618096101ed9be85d3ef0d0f1e0d2738cd0758b9/open_clip_torch-2.10.1-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 172 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9c/fa/d51b31e42d1c620e647e33d5d66213428621510721c918321c759cdb7eca/open_clip_torch-2.10.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 281 kB/s eta 0:00:01     |█▋                              | 71 kB 766 kB/s eta 0:00:02
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/04/29/54d496b431cbc2da20d6eb18f327ed80280faeacfd5576e5e8cdffacbded/open_clip_torch-2.9.3-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 57 kB/s eta 0:00:011
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/af/7d/24cebce30f4b20cfad03111e97cf21bc517494b5c1ce1aa1257bce304364/open_clip_torch-2.9.2-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 163 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b8/0c/c41975c8fb8b4d43c270dd206ed9df8c2b24920674fffe5790b31fdae1ca/open_clip_torch-2.9.1-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 896 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a8/f6/a30f10401f80b6b70d402c0bf474369e887fc7d0a398c6125325b722dbcd/open_clip_torch-2.8.2-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 187 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/36/51/8af27293eb683ca9b8d75e611b57c0858e6bb96f97b37ddeb6102e58b2bf/open_clip_torch-2.8.1-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 628 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ef/eb/b36692ddb2b52437f24d6fcfb91b8e69a03ae0e0293e106e8634b3e869b7/open_clip_torch-2.8.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 690 kB/s eta 0:00:01
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7f/80/77b44d0a3c08e2c64fed22f4f0b9049bdf6fddcadbce57453c706c549d65/open_clip_torch-2.7.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 24.0 MB/s eta 0:00:01
# Collecting PyQt5-sip<13,>=12.11
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2e/b4/3279ea444a8c196c564e5608b17915e0e534d5ddca1cc5d5139e5fa6e372/PyQt5_sip-12.11.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (344 kB)
#      |████████████████████████████████| 344 kB 72.1 MB/s eta 0:00:01
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/83/d4/241a6a518d0bcf0a9fcdcbad5edfed18d43e884317eab8d5230a2b27e206/PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      |████████████████████████████████| 59.9 MB 74.3 MB/s eta 0:00:01
# Requirement already satisfied: wcwidth>=0.2.5 in /environment/miniconda3/lib/python3.7/site-packages (from ftfy->clip@ git+https://github.com/openai/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1->-r requirements/tests.txt (line 1)) (0.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->-r requirements/runtime.txt (line 9)) (4.28.3)
# Requirement already satisfied: python-dateutil>=2.7 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->-r requirements/runtime.txt (line 9)) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->-r requirements/runtime.txt (line 9)) (6.3.2)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->-r requirements/runtime.txt (line 9)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->-r requirements/runtime.txt (line 9)) (1.3.2)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6f/78/15e11f84531c3e4e078ed2faa4e6e078ef2a0c06c6275020bc10c3865e9c/llvmlite-0.39.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 86.6 MB/s eta 0:00:01
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine->-r requirements/runtime.txt (line 9)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine->-r requirements/runtime.txt (line 9)) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /environment/miniconda3/lib/python3.7/site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->mmengine->-r requirements/runtime.txt (line 9)) (0.1.2)
# Requirement already satisfied: networkx>=2.2 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->-r requirements/runtime.txt (line 4)) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->-r requirements/runtime.txt (line 4)) (2021.11.2)
# Requirement already satisfied: imageio>=2.4.1 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->-r requirements/runtime.txt (line 4)) (2.13.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->-r requirements/runtime.txt (line 4)) (1.2.0)
# Building wheels for collected packages: clip, face-alignment, filterpy, pycocotools
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369397 sha256=0490951968c032f3a9f54a4f1920859c948c9d98dd472beb436f00b8b01d1c87
#   Stored in directory: /home/featurize/.cache/pip/wheels/69/32/fe/e5dab0ac81ac6b332d5856c2e46221af469fdbe80ee4c3ae9c
#   Building wheel for face-alignment (setup.py) ... done
#   Created wheel for face-alignment: filename=face_alignment-1.3.5-py2.py3-none-any.whl size=28237 sha256=d4a0f44cebcdb1827ce733fbbc03531b45abdd8c504a728f37126748799b8b52
#   Stored in directory: /home/featurize/.cache/pip/wheels/b0/e9/dc/68703b5a2d30ec3e32e0533926b6c0043c5a6ed601e05116d2
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110451 sha256=099ac9db1ff9d96740b955da6481bb788436db3e6775b6e137f3ae97aa9d4ccc
#   Stored in directory: /home/featurize/.cache/pip/wheels/60/79/e4/a6df5e482863f893b95d3e95627d744cb2e57b26b44ec20b22
#   Building wheel for pycocotools (PEP 517) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp37-cp37m-linux_x86_64.whl size=373927 sha256=71b2ab11fad6f2eb30e3811aab88953562dcdf92864831d20cc28aac4d7ae85e
#   Stored in directory: /home/featurize/.cache/pip/wheels/f8/94/70/046149e666bd5812b7de6b87a28dcef238f7162f4108e0b3d8
# Successfully built clip face-alignment filterpy pycocotools
# Installing collected packages: llvmlite, filelock, tokenizers, terminaltables, regex, PyQt5-sip, PyQt5-Qt5, pycocotools, py, numba, iniconfig, huggingface-hub, ftfy, filterpy, exceptiongroup, transformers, resize-right, pytest, PyQt5, open-clip-torch, mmdet, lpips, lmdb, interrogate, imageio-ffmpeg, facexlib, face-alignment, einops, coverage, clip, av
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.8
#     Uninstalling imageio-ffmpeg-0.4.8:
#       Successfully uninstalled imageio-ffmpeg-0.4.8
# Successfully installed PyQt5-5.15.9 PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.1 av-10.0.0 clip-1.0 coverage-6.5.0 einops-0.6.0 exceptiongroup-1.1.0 face-alignment-1.3.5 facexlib-0.2.5 filelock-3.9.0 filterpy-1.4.5 ftfy-6.1.1 huggingface-hub-0.12.1 imageio-ffmpeg-0.4.4 iniconfig-2.0.0 interrogate-1.5.0 llvmlite-0.39.1 lmdb-1.4.0 lpips-0.1.4 mmdet-3.0.0rc6 numba-0.56.4 open-clip-torch-2.7.0 py-1.11.0 pycocotools-2.0.6 pytest-7.2.1 regex-2022.10.31 resize-right-0.0.2 terminaltables-3.1.10 tokenizers-0.13.2 transformers-4.26.1
# Using pip 21.1.3 from /environment/miniconda3/lib/python3.7/site-packages/pip (python 3.7)
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-pubpmcxf
# Created temporary directory: /tmp/pip-req-tracker-j5ud3ts2
# Initialized build tracking at /tmp/pip-req-tracker-j5ud3ts2
# Created build tracker: /tmp/pip-req-tracker-j5ud3ts2
# Entered build tracker: /tmp/pip-req-tracker-j5ud3ts2
# Created temporary directory: /tmp/pip-install-vr2sds5w
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Obtaining file:///home/featurize/work/2/mmediting
#   Added file:///home/featurize/work/2/mmediting to build tracker '/tmp/pip-req-tracker-j5ud3ts2'
#     Running setup.py (path:/home/featurize/work/2/mmediting/setup.py) egg_info for package from file:///home/featurize/work/2/mmediting
#     Created temporary directory: /tmp/pip-pip-egg-info-524r6ff_
#     Running command python setup.py egg_info
#     running egg_info
#     creating /tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info
#     writing /tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info/dependency_links.txt
#     writing requirements to /tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info/requires.txt
#     writing top-level names to /tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmedit/.mim/VERSION'
#     warning: no files found matching 'mmedit/.mim/model-index.yml'
#     warning: no files found matching '*.py' under directory 'mmedit/.mim/configs'
#     warning: no files found matching '*.yml' under directory 'mmedit/.mim/configs'
#     warning: no files found matching '*.sh' under directory 'mmedit/.mim/tools'
#     warning: no files found matching '*.py' under directory 'mmedit/.mim/tools'
#     warning: no files found matching '*.py' under directory 'mmedit/.mim/demo'
#     writing manifest file '/tmp/pip-pip-egg-info-524r6ff_/mmedit.egg-info/SOURCES.txt'
#   Source in /home/featurize/work/2/mmediting has version 1.0.0rc5, which satisfies requirement mmedit==1.0.0rc5 from file:///home/featurize/work/2/mmediting
#   Removed mmedit==1.0.0rc5 from file:///home/featurize/work/2/mmediting from build tracker '/tmp/pip-req-tracker-j5ud3ts2'
# Requirement already satisfied: av in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (10.0.0)
# Requirement already satisfied: einops in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (0.6.0)
# Requirement already satisfied: face-alignment in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (1.3.5)
# Requirement already satisfied: facexlib in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (0.2.5)
# Requirement already satisfied: lmdb in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (1.4.0)
# Requirement already satisfied: lpips in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (0.1.4)
# Requirement already satisfied: mmcv>=2.0.0rc1 in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (2.0.0rc4)
# Requirement already satisfied: mmengine in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (0.6.0)
# Requirement already satisfied: numpy in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (1.21.4)
# Requirement already satisfied: opencv-python!=4.5.5.62,!=4.5.5.64 in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (4.5.4.60)
# Requirement already satisfied: Pillow in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (8.4.0)
# Requirement already satisfied: resize_right in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (0.0.2)
# Requirement already satisfied: tensorboard in /environment/miniconda3/lib/python3.7/site-packages (from mmedit==1.0.0rc5) (2.7.0)
# Requirement already satisfied: pyyaml in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->mmedit==1.0.0rc5) (6.0)
# Requirement already satisfied: packaging in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->mmedit==1.0.0rc5) (21.3)
# Requirement already satisfied: yapf in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->mmedit==1.0.0rc5) (0.31.0)
# Requirement already satisfied: addict in /environment/miniconda3/lib/python3.7/site-packages (from mmcv>=2.0.0rc1->mmedit==1.0.0rc5) (2.4.0)
# Requirement already satisfied: termcolor in /environment/miniconda3/lib/python3.7/site-packages (from mmengine->mmedit==1.0.0rc5) (1.1.0)
# Requirement already satisfied: rich in /environment/miniconda3/lib/python3.7/site-packages (from mmengine->mmedit==1.0.0rc5) (13.3.1)
# Requirement already satisfied: matplotlib in /environment/miniconda3/lib/python3.7/site-packages (from mmengine->mmedit==1.0.0rc5) (3.5.0)
# Requirement already satisfied: scikit-image in /environment/miniconda3/lib/python3.7/site-packages (from face-alignment->mmedit==1.0.0rc5) (0.19.0)
# Requirement already satisfied: scipy>=0.17 in /environment/miniconda3/lib/python3.7/site-packages (from face-alignment->mmedit==1.0.0rc5) (1.7.3)
# Requirement already satisfied: numba in /environment/miniconda3/lib/python3.7/site-packages (from face-alignment->mmedit==1.0.0rc5) (0.56.4)
# Requirement already satisfied: torch in /environment/miniconda3/lib/python3.7/site-packages (from face-alignment->mmedit==1.0.0rc5) (1.10.1+cu113)
# Requirement already satisfied: tqdm in /environment/miniconda3/lib/python3.7/site-packages (from face-alignment->mmedit==1.0.0rc5) (4.61.2)
# Requirement already satisfied: filterpy in /environment/miniconda3/lib/python3.7/site-packages (from facexlib->mmedit==1.0.0rc5) (1.4.5)
# Requirement already satisfied: torchvision in /environment/miniconda3/lib/python3.7/site-packages (from facexlib->mmedit==1.0.0rc5) (0.11.2+cu113)
# Requirement already satisfied: typing-extensions in /environment/miniconda3/lib/python3.7/site-packages (from torch->face-alignment->mmedit==1.0.0rc5) (4.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->mmedit==1.0.0rc5) (3.0.6)
# Requirement already satisfied: cycler>=0.10 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->mmedit==1.0.0rc5) (0.11.0)
# Requirement already satisfied: setuptools-scm>=4 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->mmedit==1.0.0rc5) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->mmedit==1.0.0rc5) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->mmedit==1.0.0rc5) (4.28.3)
# Requirement already satisfied: python-dateutil>=2.7 in /environment/miniconda3/lib/python3.7/site-packages (from matplotlib->mmengine->mmedit==1.0.0rc5) (2.8.2)
# Requirement already satisfied: six>=1.5 in /environment/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->mmengine->mmedit==1.0.0rc5) (1.16.0)
# Requirement already satisfied: setuptools in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->mmengine->mmedit==1.0.0rc5) (52.0.0.post20210125)
# Requirement already satisfied: tomli>=1.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from setuptools-scm>=4->matplotlib->mmengine->mmedit==1.0.0rc5) (1.2.2)
# Requirement already satisfied: importlib-metadata in /environment/miniconda3/lib/python3.7/site-packages (from numba->face-alignment->mmedit==1.0.0rc5) (4.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /environment/miniconda3/lib/python3.7/site-packages (from numba->face-alignment->mmedit==1.0.0rc5) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /environment/miniconda3/lib/python3.7/site-packages (from importlib-metadata->numba->face-alignment->mmedit==1.0.0rc5) (3.6.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine->mmedit==1.0.0rc5) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /environment/miniconda3/lib/python3.7/site-packages (from rich->mmengine->mmedit==1.0.0rc5) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /environment/miniconda3/lib/python3.7/site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich->mmengine->mmedit==1.0.0rc5) (0.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->mmedit==1.0.0rc5) (1.2.0)
# Requirement already satisfied: imageio>=2.4.1 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->mmedit==1.0.0rc5) (2.13.3)
# Requirement already satisfied: networkx>=2.2 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->mmedit==1.0.0rc5) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /environment/miniconda3/lib/python3.7/site-packages (from scikit-image->face-alignment->mmedit==1.0.0rc5) (2021.11.2)
# Requirement already satisfied: grpcio>=1.24.3 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (1.42.0)
# Requirement already satisfied: protobuf>=3.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (3.19.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (2.0.2)
# Requirement already satisfied: wheel>=0.26 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (0.36.2)
# Requirement already satisfied: markdown>=2.6.8 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (2.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (2.24.0)
# Requirement already satisfied: absl-py>=0.4 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /environment/miniconda3/lib/python3.7/site-packages (from tensorboard->mmedit==1.0.0rc5) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmedit==1.0.0rc5) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmedit==1.0.0rc5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard->mmedit==1.0.0rc5) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /environment/miniconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->mmedit==1.0.0rc5) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /environment/miniconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->mmedit==1.0.0rc5) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->mmedit==1.0.0rc5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->mmedit==1.0.0rc5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->mmedit==1.0.0rc5) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /environment/miniconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->mmedit==1.0.0rc5) (1.25.11)
# Requirement already satisfied: oauthlib>=3.0.0 in /environment/miniconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->mmedit==1.0.0rc5) (3.1.1)
# Created temporary directory: /tmp/pip-unpack-9e25ou10
# Installing collected packages: mmedit
#   Running setup.py develop for mmedit
#     Running command /environment/miniconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/home/featurize/work/2/mmediting/setup.py'"'"'; __file__='"'"'/home/featurize/work/2/mmediting/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps
#     running develop
#     running egg_info
#     creating mmedit.egg-info
#     writing mmedit.egg-info/PKG-INFO
#     writing dependency_links to mmedit.egg-info/dependency_links.txt
#     writing requirements to mmedit.egg-info/requires.txt
#     writing top-level names to mmedit.egg-info/top_level.txt
#     writing manifest file 'mmedit.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching 'mmedit/.mim/VERSION'
#     writing manifest file 'mmedit.egg-info/SOURCES.txt'
#     running build_ext
#     Creating /environment/miniconda3/lib/python3.7/site-packages/mmedit.egg-link (link to .)
#     Adding mmedit 1.0.0rc5 to easy-install.pth file
#
#     Installed /home/featurize/work/2/mmediting
# Successfully installed mmedit-1.0.0rc5
# Removed build tracker: '/tmp/pip-req-tracker-j5ud3ts2'

# %% [markdown]
# ## 创建一些文件夹

# %%
# 创建 outputs 文件夹，用于存放生成结果
os.mkdir('outputs')

# 创建 data 文件夹，用于存放图像数据集
os.mkdir('data')

# 创建 checkpoints 文件夹，用于存放模型权重文件
os.mkdir('checkpoints')

# 创建 work_dirs 文件夹，用于存放训练结果及趣味 demo 输出结果
os.mkdir('work_dirs')

# %% [markdown]
# ## 下载一些图像和视频素材至`data`目录

# %%
## 一些风景照素材，拍摄者：同济子豪兄
# 同济大学嘉定校区
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/tongji_campus.jpg -O data/tongji_campus.jpg
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/tongji_library.jpg -O data/tongji_library.jpg
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/tongji_video.mp4 -O data/tongji_video.mp4

# 舟山群岛-枸杞岛
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/gouqi_island.jpg -O data/gouqi_island.jpg
# 玉龙雪山
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/yulong_mountain.jpg -O data/yulong_mountain.jpg
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/yulong_mountain.mp4 -O data/yulong_mountain.mp4
# 五台山
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/wutai_mountain.jpg -O data/wutai_mountain.jpg

# 一些摄影作品，拍摄者：张子豪
# 创建 memory 文件夹，
# !mkdir data/memory
# 旧金山圆石滩高尔夫球场
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_san.jpg -O data/memory/memory_san.jpg 
# 南京玄武湖公园
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_nanjing.jpg -O data/memory/memory_nanjing.jpg
# 重庆鹅岭公园
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_chongqing.jpg -O data/memory/memory_chongqing.jpg
# 同济大学嘉定校区
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_tongji1.jpg -O data/memory/memory_tongji1.jpg
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_tongji2.jpg -O data/memory/memory_tongji2.jpg
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_tongji3.jpg -O data/memory/memory_tongji3.jpg

## 素材图片，来源：pexel
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/horse.jpeg -O data/horse.jpeg
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/zebras.jpeg -O data/zebras.jpeg

# !wget https://jsd.cdn.zzko.cn/gh/wenbo0117/sucaiku@main/mergedGT05.jpg -O data/mergedGT05.jpg
# !wget https://jsd.cdn.zzko.cn/gh/wenbo0117/sucaiku@main/trimapGT05.png -O data/trimapGT05.png
# Out:
# --2023-02-28 15:37:10--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/tongji_campus.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 4874351 (4.6M) [image/jpeg]
# 正在保存至: “data/tongji_campus.jpg”
#
# data/tongji_campus. 100%[===================>]   4.65M  12.7MB/s    用时 0.4s
#
# 2023-02-28 15:37:11 (12.7 MB/s) - 已保存 “data/tongji_campus.jpg” [4874351/4874351])
#
# --2023-02-28 15:37:11--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/tongji_library.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 3737962 (3.6M) [image/jpeg]
# 正在保存至: “data/tongji_library.jpg”
#
# data/tongji_library 100%[===================>]   3.56M  10.5MB/s    用时 0.3s
#
# 2023-02-28 15:37:12 (10.5 MB/s) - 已保存 “data/tongji_library.jpg” [3737962/3737962])
#
# --2023-02-28 15:37:12--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/tongji_video.mp4
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 25971165 (25M) [video/mp4]
# 正在保存至: “data/tongji_video.mp4”
#
# data/tongji_video.m 100%[===================>]  24.77M  36.7MB/s    用时 0.7s
#
# 2023-02-28 15:37:13 (36.7 MB/s) - 已保存 “data/tongji_video.mp4” [25971165/25971165])
#
# --2023-02-28 15:37:13--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/gouqi_island.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 5786552 (5.5M) [image/jpeg]
# 正在保存至: “data/gouqi_island.jpg”
#
# data/gouqi_island.j 100%[===================>]   5.52M  10.8MB/s    用时 0.5s
#
# 2023-02-28 15:37:14 (10.8 MB/s) - 已保存 “data/gouqi_island.jpg” [5786552/5786552])
#
# --2023-02-28 15:37:14--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/yulong_mountain.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 2733096 (2.6M) [image/jpeg]
# 正在保存至: “data/yulong_mountain.jpg”
#
# data/yulong_mountai 100%[===================>]   2.61M  7.78MB/s    用时 0.3s
#
# 2023-02-28 15:37:14 (7.78 MB/s) - 已保存 “data/yulong_mountain.jpg” [2733096/2733096])
#
# --2023-02-28 15:37:15--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/yulong_mountain.mp4
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 37303594 (36M) [video/mp4]
# 正在保存至: “data/yulong_mountain.mp4”
#
# data/yulong_mountai 100%[===================>]  35.58M  30.5MB/s    用时 1.2s
#
# 2023-02-28 15:37:16 (30.5 MB/s) - 已保存 “data/yulong_mountain.mp4” [37303594/37303594])
#
# --2023-02-28 15:37:16--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/wutai_mountain.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 2055063 (2.0M) [image/jpeg]
# 正在保存至: “data/wutai_mountain.jpg”
#
# data/wutai_mountain 100%[===================>]   1.96M  6.48MB/s    用时 0.3s
#
# 2023-02-28 15:37:17 (6.48 MB/s) - 已保存 “data/wutai_mountain.jpg” [2055063/2055063])
#
# --2023-02-28 15:37:17--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_san.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 5376981 (5.1M) [image/jpeg]
# 正在保存至: “data/memory/memory_san.jpg”
#
# data/memory/memory_ 100%[===================>]   5.13M  14.1MB/s    用时 0.4s
#
# 2023-02-28 15:37:18 (14.1 MB/s) - 已保存 “data/memory/memory_san.jpg” [5376981/5376981])
#
# --2023-02-28 15:37:18--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_nanjing.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 5151902 (4.9M) [image/jpeg]
# 正在保存至: “data/memory/memory_nanjing.jpg”
#
# data/memory/memory_ 100%[===================>]   4.91M  13.4MB/s    用时 0.4s
#
# 2023-02-28 15:37:18 (13.4 MB/s) - 已保存 “data/memory/memory_nanjing.jpg” [5151902/5151902])
#
# --2023-02-28 15:37:18--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_chongqing.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 2457991 (2.3M) [image/jpeg]
# 正在保存至: “data/memory/memory_chongqing.jpg”
#
# data/memory/memory_ 100%[===================>]   2.34M  7.33MB/s    用时 0.3s
#
# 2023-02-28 15:37:19 (7.33 MB/s) - 已保存 “data/memory/memory_chongqing.jpg” [2457991/2457991])
#
# --2023-02-28 15:37:19--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_tongji1.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 4874351 (4.6M) [image/jpeg]
# 正在保存至: “data/memory/memory_tongji1.jpg”
#
# data/memory/memory_ 100%[===================>]   4.65M  12.9MB/s    用时 0.4s
#
# 2023-02-28 15:37:20 (12.9 MB/s) - 已保存 “data/memory/memory_tongji1.jpg” [4874351/4874351])
#
# --2023-02-28 15:37:20--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_tongji2.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 3737962 (3.6M) [image/jpeg]
# 正在保存至: “data/memory/memory_tongji2.jpg”
#
# data/memory/memory_ 100%[===================>]   3.56M  10.3MB/s    用时 0.3s
#
# 2023-02-28 15:37:21 (10.3 MB/s) - 已保存 “data/memory/memory_tongji2.jpg” [3737962/3737962])
#
# --2023-02-28 15:37:21--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/memory/memory_tongji3.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 5510850 (5.3M) [image/jpeg]
# 正在保存至: “data/memory/memory_tongji3.jpg”
#
# data/memory/memory_ 100%[===================>]   5.25M  14.6MB/s    用时 0.4s
#
# 2023-02-28 15:37:21 (14.6 MB/s) - 已保存 “data/memory/memory_tongji3.jpg” [5510850/5510850])
#
# --2023-02-28 15:37:21--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/horse.jpeg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 511617 (500K) [image/jpeg]
# 正在保存至: “data/horse.jpeg”
#
# data/horse.jpeg     100%[===================>] 499.63K  2.28MB/s    用时 0.2s
#
# 2023-02-28 15:37:22 (2.28 MB/s) - 已保存 “data/horse.jpeg” [511617/511617])
#
# --2023-02-28 15:37:22--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220322-mmgeneration/images/zebras.jpeg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 457634 (447K) [image/jpeg]
# 正在保存至: “data/zebras.jpeg”
#
# data/zebras.jpeg    100%[===================>] 446.91K  2.06MB/s    用时 0.2s
#
# 2023-02-28 15:37:23 (2.06 MB/s) - 已保存 “data/zebras.jpeg” [457634/457634])
#
# --2023-02-28 15:37:23--  https://jsd.cdn.zzko.cn/gh/wenbo0117/sucaiku@main/mergedGT05.jpg
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 155165 (152K) [image/jpeg]
# 正在保存至: “data/mergedGT05.jpg”
#
# data/mergedGT05.jpg 100%[===================>] 151.53K   849KB/s    用时 0.2s
#
# 2023-02-28 15:37:24 (849 KB/s) - 已保存 “data/mergedGT05.jpg” [155165/155165])
#
# --2023-02-28 15:37:24--  https://jsd.cdn.zzko.cn/gh/wenbo0117/sucaiku@main/trimapGT05.png
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 9790 (9.6K) [image/png]
# 正在保存至: “data/trimapGT05.png”
#
# data/trimapGT05.png 100%[===================>]   9.56K  --.-KB/s    用时 0s
#
# 2023-02-28 15:37:25 (59.4 MB/s) - 已保存 “data/trimapGT05.png” [9790/9790])

# %% [markdown]
# ## 下载图片和视频

# %%
# 创建存放素材的文件夹
# !mkdir -p ./resources/input/translation
# !mkdir -p ./resources/output/translation

# %%
# 查看所有资源
# !python demo/download_inference_resources.py --print-all
# 查看所有任务类型
# !python demo/download_inference_resources.py --print-task-type
# 查看特定任务的资源
# !python demo/download_inference_resources.py --print-task 'Inpainting'
# 将所有资源下载到默认目录'../resources'
# !python demo/download_inference_resources.py
# 下载一个任务的资源
# !python demo/download_inference_resources.py --task 'Inpainting'
# 下载到您想要的目录
# !python demo/download_inference_resources.py --root-dir 'resources'
# Out:
# all inference resources:
# Matting
# https://download.openmmlab.com/mmediting/resources/input/matting/GT05.jpg
# https://download.openmmlab.com/mmediting/resources/input/matting/GT05_trimap.jpg
# https://download.openmmlab.com/mmediting/resources/input/matting/readme.md
# Inpainting
# https://download.openmmlab.com/mmediting/resources/input/inpainting/bbox_mask.png
# https://download.openmmlab.com/mmediting/resources/input/inpainting/celeba_test.png
# https://download.openmmlab.com/mmediting/resources/input/inpainting/readme.md
# Image Super-Resolution
# https://download.openmmlab.com/mmediting/resources/input/restoration/000001.png
# https://download.openmmlab.com/mmediting/resources/input/restoration/0901x2.png
# https://download.openmmlab.com/mmediting/resources/input/restoration/readme.md
# Image2Image Translation
# https://download.openmmlab.com/mmediting/resources/input/translation/gt_mask_0.png
# https://download.openmmlab.com/mmediting/resources/input/translation/readme.md
# Video Interpolation
# https://download.openmmlab.com/mmediting/resources/input/video_interpolation/b-3LLDhc4EU_000000_000010.mp4
# https://download.openmmlab.com/mmediting/resources/input/video_interpolation/readme.md
# Video Super-Resolution
# https://download.openmmlab.com/mmediting/resources/input/video_restoration/QUuC4vJs_000084_000094_400x320.mp4
# https://download.openmmlab.com/mmediting/resources/input/video_restoration/readme.md
# https://download.openmmlab.com/mmediting/resources/input/video_restoration/v_Basketball_g01_c01.avi
# all task type:
# Matting
# Inpainting
# Image Super-Resolution
# Image2Image Translation
# Video Interpolation
# Video Super-Resolution
# RESOURCES of task Inpainting:
# https://download.openmmlab.com/mmediting/resources/input/inpainting/bbox_mask.png
# https://download.openmmlab.com/mmediting/resources/input/inpainting/celeba_test.png
# https://download.openmmlab.com/mmediting/resources/input/inpainting/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/matting/GT05.jpg to demo/../resources/input/matting/GT05.jpg
# Download finished: https://download.openmmlab.com/mmediting/resources/input/matting/GT05_trimap.jpg to demo/../resources/input/matting/GT05_trimap.jpg
# Download finished: https://download.openmmlab.com/mmediting/resources/input/matting/readme.md to demo/../resources/input/matting/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/bbox_mask.png to demo/../resources/input/inpainting/bbox_mask.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/celeba_test.png to demo/../resources/input/inpainting/celeba_test.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/readme.md to demo/../resources/input/inpainting/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/restoration/000001.png to demo/../resources/input/restoration/000001.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/restoration/0901x2.png to demo/../resources/input/restoration/0901x2.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/restoration/readme.md to demo/../resources/input/restoration/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/translation/gt_mask_0.png to demo/../resources/input/translation/gt_mask_0.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/translation/readme.md to demo/../resources/input/translation/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_interpolation/b-3LLDhc4EU_000000_000010.mp4 to demo/../resources/input/video_interpolation/b-3LLDhc4EU_000000_000010.mp4
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_interpolation/readme.md to demo/../resources/input/video_interpolation/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_restoration/QUuC4vJs_000084_000094_400x320.mp4 to demo/../resources/input/video_restoration/QUuC4vJs_000084_000094_400x320.mp4
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_restoration/readme.md to demo/../resources/input/video_restoration/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_restoration/v_Basketball_g01_c01.avi to demo/../resources/input/video_restoration/v_Basketball_g01_c01.avi
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/bbox_mask.png to demo/../resources/input/inpainting/bbox_mask.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/celeba_test.png to demo/../resources/input/inpainting/celeba_test.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/readme.md to demo/../resources/input/inpainting/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/matting/GT05.jpg to demo/resources/input/matting/GT05.jpg
# Download finished: https://download.openmmlab.com/mmediting/resources/input/matting/GT05_trimap.jpg to demo/resources/input/matting/GT05_trimap.jpg
# Download finished: https://download.openmmlab.com/mmediting/resources/input/matting/readme.md to demo/resources/input/matting/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/bbox_mask.png to demo/resources/input/inpainting/bbox_mask.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/celeba_test.png to demo/resources/input/inpainting/celeba_test.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/inpainting/readme.md to demo/resources/input/inpainting/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/restoration/000001.png to demo/resources/input/restoration/000001.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/restoration/0901x2.png to demo/resources/input/restoration/0901x2.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/restoration/readme.md to demo/resources/input/restoration/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/translation/gt_mask_0.png to demo/resources/input/translation/gt_mask_0.png
# Download finished: https://download.openmmlab.com/mmediting/resources/input/translation/readme.md to demo/resources/input/translation/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_interpolation/b-3LLDhc4EU_000000_000010.mp4 to demo/resources/input/video_interpolation/b-3LLDhc4EU_000000_000010.mp4
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_interpolation/readme.md to demo/resources/input/video_interpolation/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_restoration/QUuC4vJs_000084_000094_400x320.mp4 to demo/resources/input/video_restoration/QUuC4vJs_000084_000094_400x320.mp4
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_restoration/readme.md to demo/resources/input/video_restoration/readme.md
# Download finished: https://download.openmmlab.com/mmediting/resources/input/video_restoration/v_Basketball_g01_c01.avi to demo/resources/input/video_restoration/v_Basketball_g01_c01.avi

# %% [markdown]
# ## 检查是否安装成功

# %%
# !cd ~
# !python -c "import mmedit; print(mmedit.__version__)"
# 输出版本正确则安装成功
# Out:
# 1.0.0rc5
